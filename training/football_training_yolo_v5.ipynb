# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (8.3.205)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (3.10.6)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (7.1.0)
# Requirement already satisfied: polars in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (1.34.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Requirement already satisfied: polars-runtime-32==1.34.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from polars->ultralytics) (1.34.0)
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (2025.10.5)
# Collecting idna==3.7 (from roboflow)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (3.10.6)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (2.2.6)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (11.3.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp310-cp310-win_amd64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from roboflow) (6.0.3)
# Collecting requests-toolbelt (from roboflow)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: colorama in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib->roboflow) (4.60.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from matplotlib->roboflow) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\praba\anaconda3\envs\open_cv_env\lib\site-packages (from requests->roboflow) (3.4.3)
# Downloading roboflow-1.2.11-py3-none-any.whl (89 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Downloading pi_heif-1.1.1-cp310-cp310-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.9 MB 1.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/1.9 MB 1.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/1.9 MB 1.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.0/1.9 MB 915.5 kB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 959.4 kB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 1.1 MB/s  0:00:01
# Downloading pillow_avif_plugin-1.5.2-cp310-cp310-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.9 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.9 MB 1.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.9 MB 1.5 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.9 MB 1.5 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.9 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.9 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/9.9 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.9 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.9 MB 1.1 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.6/9.9 MB 1.1 MB/s eta 0:00:07
#    ---------- ----------------------------- 2.6/9.9 MB 1.1 MB/s eta 0:00:07
#    ----------- ---------------------------- 2.9/9.9 MB 1.1 MB/s eta 0:00:07
#    ------------ --------------------------- 3.1/9.9 MB 1.1 MB/s eta 0:00:07
#    ------------ --------------------------- 3.1/9.9 MB 1.1 MB/s eta 0:00:07
#    ------------- -------------------------- 3.4/9.9 MB 987.0 kB/s eta 0:00:07
#    -------------- ------------------------- 3.7/9.9 MB 1.0 MB/s eta 0:00:07
#    --------------- ------------------------ 3.9/9.9 MB 1.0 MB/s eta 0:00:06
#    ------------------ --------------------- 4.5/9.9 MB 1.1 MB/s eta 0:00:05
#    ------------------- -------------------- 4.7/9.9 MB 1.1 MB/s eta 0:00:05
#    --------------------- ------------------ 5.2/9.9 MB 1.2 MB/s eta 0:00:04
#    --------------------- ------------------ 5.2/9.9 MB 1.2 MB/s eta 0:00:04
#    --------------------- ------------------ 5.2/9.9 MB 1.2 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.5/9.9 MB 1.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 5.8/9.9 MB 1.1 MB/s eta 0:00:04
#    ------------------------- -------------- 6.3/9.9 MB 1.1 MB/s eta 0:00:04
#    ------------------------- -------------- 6.3/9.9 MB 1.1 MB/s eta 0:00:04
#    ------------------------- -------------- 6.3/9.9 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 6.6/9.9 MB 1.0 MB/s eta 0:00:04
#    -------------------------- ------------- 6.6/9.9 MB 1.0 MB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.9 MB 1.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.3/9.9 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 7.6/9.9 MB 1.1 MB/s eta 0:00:03
#    -------------------------------- ------- 8.1/9.9 MB 1.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 8.7/9.9 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------- -- 9.2/9.9 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 1.2 MB/s  0:00:08
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, python-dotenv, pi-heif, opencv-python-headless, idna, requests-toolbelt, roboflow
#
#    ---------------------------------------- 0/8 [pillow-avif-plugin]
#    ----- ---------------------------------- 1/8 [filetype]
#    ---------- ----------------------------- 2/8 [python-dotenv]
#    --------------- ------------------------ 3/8 [pi-heif]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#   Attempting uninstall: idna
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#     Found existing installation: idna 3.10
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#     Uninstalling idna-3.10:
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    ------------------------- -------------- 5/8 [idna]
#       Successfully uninstalled idna-3.10
#    ------------------------- -------------- 5/8 [idna]
#    ------------------------- -------------- 5/8 [idna]
#    ------------------------------ --------- 6/8 [requests-toolbelt]
#    ------------------------------ --------- 6/8 [requests-toolbelt]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ---------------------------------------- 8/8 [roboflow]
#
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-avif-plugin-1.5.2 python-dotenv-1.1.1 requests-toolbelt-1.0.0 roboflow-1.2.11

# %% [markdown]
# # Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="3205MH29k2z3u5Ejc3HU") # THIS API KEY IS REVOKED. PLEASE USE YOUR OWN API KEY
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov5pytorch:: 100%|██████████| 148663/148663 [00:41<00:00, 3621.65it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:06<00:00, 222.41it/s]

# %%
dataset.location
# Out:
# '/mnt/d/AI_youtube_channel/videos/015.football_project/football_analysis/training/football-players-detection-1'

# %%
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train'
            )

shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test'
            )

shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid'
            )
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
